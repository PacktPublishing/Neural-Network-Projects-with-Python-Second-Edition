# %%
import data_points

import numpy as np
from timer_context import TimerContext
import keras
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.optimizers import SGD

keras.utils.set_random_seed(12)

x, y = data_points.get_points()
x = np.expand_dims(x, -1)

model = Sequential()
model.add(Input(shape=(x.shape[1], )))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation=None))
model.summary(show_trainable=True)

sgd = SGD(learning_rate=0.01)
model.compile(loss='mean_squared_error', optimizer=sgd)

with TimerContext() as timer:
    model.fit(x, y, epochs=100, verbose=False)
    print(f"Trained in {timer.duration}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ dense_2 (Dense)             │ (None, 100)           │        200 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_3 (Dense)             │ (None, 1)             │        101 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)
# Trained in 0:00:01.098280

# %%
pred = model.predict(x, verbose=False)

# %%
pred = pred.squeeze()

# %%
data_points.calc_mse(y, pred)
# Out:
# 0.09213247246174705

# %%
data_points.calc_mae(y, pred)
# Out:
# 0.26596133146386225
